# %% [markdown]
# 5) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team and rating.
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
page = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
#  a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
team = []

for i in soup.find_all("span",class_="u-hide-phablet"):
    team.append(i.text)
    
print(team)
# Out:
# ['England', 'New Zealand', 'India', 'Pakistan', 'Australia', 'South Africa', 'Bangladesh', 'Sri Lanka', 'West Indies', 'Afghanistan', 'Ireland', 'Scotland', 'Zimbabwe', 'Namibia', 'Netherlands', 'UAE', 'Oman', 'United States', 'Nepal', 'Papua New Guinea']

# %%
end_match = soup.find("td",class_="rankings-block__banner--matches").text
print(end_match)
end_point = soup.find("td",class_="rankings-block__banner--points").text
print(end_point)
end_rating = soup.find("td",class_="rankings-block__banner--rating u-text-right").text
end_rating=end_rating.replace(" ","").replace("\n","")
print(end_rating)
# Out:
# 27
# 3,226
# 119

# %%
m2 = []

for i in soup.find_all("td",class_="table-body__cell u-center-text"):
    m2.append(i.text)
    
m2
# Out:
# ['22',
#  '2,508',
#  '34',
#  '3,802',
#  '22',
#  '2,354',
#  '29',
#  '3,071',
#  '24',
#  '2,392',
#  '30',
#  '2,753',
#  '29',
#  '2,658',
#  '41',
#  '2,902',
#  '18',
#  '1,238',
#  '23',
#  '1,214',
#  '27',
#  '1,254',
#  '26',
#  '1,098',
#  '19',
#  '642',
#  '21',
#  '673',
#  '22',
#  '697',
#  '30',
#  '919',
#  '27',
#  '641',
#  '22',
#  '331',
#  '26',
#  '209']

# %%
matches = m2[0::2]
matches
# Out:
# ['22',
#  '34',
#  '22',
#  '29',
#  '24',
#  '30',
#  '29',
#  '41',
#  '18',
#  '23',
#  '27',
#  '26',
#  '19',
#  '21',
#  '22',
#  '30',
#  '27',
#  '22',
#  '26']

# %%
points = m2[1::2]
points
# Out:
# ['2,508',
#  '3,802',
#  '2,354',
#  '3,071',
#  '2,392',
#  '2,753',
#  '2,658',
#  '2,902',
#  '1,238',
#  '1,214',
#  '1,254',
#  '1,098',
#  '642',
#  '673',
#  '697',
#  '919',
#  '641',
#  '331',
#  '209']

# %%
matches.insert(0,end_match)
matches
# Out:
# ['27',
#  '22',
#  '34',
#  '22',
#  '29',
#  '24',
#  '30',
#  '29',
#  '41',
#  '18',
#  '23',
#  '27',
#  '26',
#  '19',
#  '21',
#  '22',
#  '30',
#  '27',
#  '22',
#  '26']

# %%
points.insert(0,end_point)
points
# Out:
# ['3,226',
#  '2,508',
#  '3,802',
#  '2,354',
#  '3,071',
#  '2,392',
#  '2,753',
#  '2,658',
#  '2,902',
#  '1,238',
#  '1,214',
#  '1,254',
#  '1,098',
#  '642',
#  '673',
#  '697',
#  '919',
#  '641',
#  '331',
#  '209']

# %%
rating = []

for i in soup.find_all("td",class_="table-body__cell u-text-right rating"):
    rating.append(i.text)
    
rating
# Out:
# ['114',
#  '112',
#  '107',
#  '106',
#  '100',
#  '92',
#  '92',
#  '71',
#  '69',
#  '53',
#  '46',
#  '42',
#  '34',
#  '32',
#  '32',
#  '31',
#  '24',
#  '15',
#  '8']

# %%
rating.insert(0,end_rating)

# %%
data = {"Team":team[:10],"Matches":matches[0:10],"Point":points[:10],"Rating":rating[:10]}
data
# Out:
# {'Team': ['England',
#   'New Zealand',
#   'India',
#   'Pakistan',
#   'Australia',
#   'South Africa',
#   'Bangladesh',
#   'Sri Lanka',
#   'West Indies',
#   'Afghanistan'],
#  'Matches': ['27', '22', '34', '22', '29', '24', '30', '29', '41', '18'],
#  'Point': ['3,226',
#   '2,508',
#   '3,802',
#   '2,354',
#   '3,071',
#   '2,392',
#   '2,753',
#   '2,658',
#   '2,902',
#   '1,238'],
#  'Rating': ['119', '114', '112', '107', '106', '100', '92', '92', '71', '69']}

# %%
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
odi_team = pd.DataFrame(data)
odi_team
# Out:
#            Team Matches  Point Rating
# 0       England      27  3,226    119
# 1   New Zealand      22  2,508    114
# 2         India      34  3,802    112
# 3      Pakistan      22  2,354    107
# 4     Australia      29  3,071    106
# 5  South Africa      24  2,392    100
# 6    Bangladesh      30  2,753     92
# 7     Sri Lanka      29  2,658     92
# 8   West Indies      41  2,902     71
# 9   Afghanistan      18  1,238     69

# %% [markdown]
# b) Top 10 ODI Batsmen along with the records of their team and rating.

# %%
page2 = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
page2
# Out:
# <Response [200]>

# %%
odi = BeautifulSoup(page2.content)
odi
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Batting | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Batting | Player Rankings | ICC" property="og:title"/>
# ...

# %%
ba_name = odi.find("div", class_="rankings-block__banner--name-large").text
ba_name
# Out:
# 'Babar Azam'

# %%
ba_na = odi.find("div", class_="rankings-block__banner--nationality").text.replace("\n","").replace(" ","")
ba_na
# Out:
# 'PAK'

# %%
ba_ra = odi.find("div", class_="rankings-block__banner--rating").text.replace("\n","").replace(" ","")
ba_ra
# Out:
# '890'

# %%
batsman = []

for i in odi.find_all("td",class_="table-body__cell rankings-table__name name"):
    batsman.append(i.text.replace("\n",""))
    
batsman[:9]
# Out:
# ['Imam-ul-Haq',
#  'Rassie van der Dussen',
#  'Quinton de Kock',
#  'Jonny Bairstow',
#  'David Warner',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Steve Smith']

# %%
nation = []

for i in odi.find_all("span",class_="table-body__logo-text"):
    nation.append(i.text.replace("\n",""))
    
nation[:9]
# Out:
# ['PAK', 'SA', 'SA', 'ENG', 'AUS', 'IND', 'IND', 'NZ', 'AUS']

# %%
rank = []

for i in odi.find_all("td",class_="table-body__cell rating"):
    rank.append(i.text.replace("\n",""))
    
rank[:9]
# Out:
# ['779', '766', '759', '732', '725', '722', '718', '701', '697']

# %%
batsman.insert(0,ba_name)

# %%
nation.insert(0,ba_na)
rank.insert(0,ba_ra)

# %%
data1 = {"Name":batsman[:10],"Team":nation[:10],"Rating":rank[:10]}
data
# Out:
# {'Team': ['England',
#   'New Zealand',
#   'India',
#   'Pakistan',
#   'Australia',
#   'South Africa',
#   'Bangladesh',
#   'Sri Lanka',
#   'West Indies',
#   'Afghanistan'],
#  'Matches': ['27', '22', '34', '22', '29', '24', '30', '29', '41', '18'],
#  'Point': ['3,226',
#   '2,508',
#   '3,802',
#   '2,354',
#   '3,071',
#   '2,392',
#   '2,753',
#   '2,658',
#   '2,902',
#   '1,238'],
#  'Rating': ['119', '114', '112', '107', '106', '100', '92', '92', '71', '69']}

# %%
top_10_bat = pd.DataFrame(data1)

# %%
top_10_bat
# Out:
#                     Name Team Rating
# 0             Babar Azam  PAK    890
# 1            Imam-ul-Haq  PAK    779
# 2  Rassie van der Dussen   SA    766
# 3        Quinton de Kock   SA    759
# 4         Jonny Bairstow  ENG    732
# 5           David Warner  AUS    725
# 6            Virat Kohli  IND    722
# 7           Rohit Sharma  IND    718
# 8            Ross Taylor   NZ    701
# 9            Steve Smith  AUS    697

# %% [markdown]
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
page3 = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
page3
# Out:
# <Response [200]>

# %%
odi2 = BeautifulSoup(page3.content)
odi2
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" property="og:title"/>
# ...

# %%
bow_name = [odi2.find("div", class_="rankings-block__banner--name-large").text]
bow_name
# Out:
# ['Trent Boult']

# %%
bow_team = [odi2.find("div", class_="rankings-block__banner--nationality").text.replace("\n","").replace(" ","")]
bow_team
# Out:
# ['NZ']

# %%
bow_rating = [odi2.find("div", class_="rankings-block__banner--rating").text.replace("\n","").replace(" ","")]
bow_rating
# Out:
# ['775']

# %%
for i in odi2.find_all("td",class_="table-body__cell rankings-table__name name"):
    bow_name.append(i.text.replace("\n",""))
    
bow_name[:10]
# Out:
# ['Trent Boult',
#  'Josh Hazlewood',
#  'Mujeeb Ur Rahman',
#  'Shaheen Afridi',
#  'Mohammad Nabi',
#  'Mehedi Hasan',
#  'Matt Henry',
#  'Mitchell Starc',
#  'Rashid Khan',
#  'Jasprit Bumrah']

# %%
for i in odi2.find_all("span",class_="table-body__logo-text"):
    bow_team.append(i.text.replace("\n",""))
    
bow_team[:10]
# Out:
# ['NZ', 'AUS', 'AFG', 'PAK', 'AFG', 'BAN', 'NZ', 'AUS', 'AFG', 'IND']

# %%
for i in odi2.find_all("td",class_="table-body__cell rating"):
    bow_rating.append(i.text.replace("\n",""))
    
bow_rating[:10]
# Out:
# ['775', '718', '676', '661', '657', '655', '654', '653', '651', '642']

# %%
bow_data = {"Name":bow_name[:10],"Team":bow_team[:10],"Rating":bow_rating[:10]}
bow_df = pd.DataFrame(bow_data)

# %%
bow_df
# Out:
#                Name Team Rating
# 0       Trent Boult   NZ    775
# 1    Josh Hazlewood  AUS    718
# 2  Mujeeb Ur Rahman  AFG    676
# 3    Shaheen Afridi  PAK    661
# 4     Mohammad Nabi  AFG    657
# 5      Mehedi Hasan  BAN    655
# 6        Matt Henry   NZ    654
# 7    Mitchell Starc  AUS    653
# 8       Rashid Khan  AFG    651
# 9    Jasprit Bumrah  IND    642
